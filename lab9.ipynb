# %%
pip install rioxarray
# Out:
# Collecting rioxarray
#   Downloading rioxarray-0.13.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 1.6 MB/s eta 0:00:00
# Collecting rasterio>=1.1.1
#   Downloading rasterio-1.3.4-cp310-cp310-macosx_10_15_x86_64.whl (30.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.9/30.9 MB 24.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: packaging in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from rioxarray) (21.3)
# Collecting xarray>=0.17
#   Downloading xarray-2022.11.0-py3-none-any.whl (963 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 963.7/963.7 kB 27.4 MB/s eta 0:00:00
# Requirement already satisfied: pyproj>=2.2 in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from rioxarray) (3.4.0)
# Requirement already satisfied: certifi in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from pyproj>=2.2->rioxarray) (2022.9.24)
# Requirement already satisfied: click-plugins in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from rasterio>=1.1.1->rioxarray) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from rasterio>=1.1.1->rioxarray) (0.7.2)
# Requirement already satisfied: attrs in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from rasterio>=1.1.1->rioxarray) (22.1.0)
# Collecting affine
#   Downloading affine-2.3.1-py2.py3-none-any.whl (16 kB)
# Collecting snuggs>=1.4.1
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: setuptools in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from rasterio>=1.1.1->rioxarray) (65.5.0)
# Requirement already satisfied: numpy>=1.18 in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from rasterio>=1.1.1->rioxarray) (1.23.4)
# Requirement already satisfied: click>=4.0 in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from rasterio>=1.1.1->rioxarray) (8.1.3)
# Requirement already satisfied: pandas>=1.3 in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from xarray>=0.17->rioxarray) (1.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from packaging->rioxarray) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from pandas>=1.3->xarray>=0.17->rioxarray) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from pandas>=1.3->xarray>=0.17->rioxarray) (2022.5)
# Requirement already satisfied: six>=1.5 in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas>=1.3->xarray>=0.17->rioxarray) (1.16.0)
# Installing collected packages: affine, snuggs, rasterio, xarray, rioxarray
# Successfully installed affine-2.3.1 rasterio-1.3.4 rioxarray-0.13.1 snuggs-1.4.7 xarray-2022.11.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install earthpy
# Out:
# Collecting earthpy
#   Downloading earthpy-0.9.4-py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 9.4 MB/s eta 0:00:00:00:010:01
# Requirement already satisfied: geopandas in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from earthpy) (0.11.1)
# Requirement already satisfied: rasterio in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from earthpy) (1.3.4)
# Collecting scikit-image
#   Downloading scikit_image-0.19.3-cp310-cp310-macosx_10_13_x86_64.whl (13.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 23.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: matplotlib>=2.0.0 in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from earthpy) (3.6.1)
# Requirement already satisfied: requests in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from earthpy) (2.28.1)
# Requirement already satisfied: numpy>=1.14.0 in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from earthpy) (1.23.4)
# Requirement already satisfied: contourpy>=1.0.1 in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from matplotlib>=2.0.0->earthpy) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from matplotlib>=2.0.0->earthpy) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from matplotlib>=2.0.0->earthpy) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from matplotlib>=2.0.0->earthpy) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from matplotlib>=2.0.0->earthpy) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from matplotlib>=2.0.0->earthpy) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from matplotlib>=2.0.0->earthpy) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from matplotlib>=2.0.0->earthpy) (21.3)
# Requirement already satisfied: fiona>=1.8 in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from geopandas->earthpy) (1.8.22)
# Requirement already satisfied: shapely<2,>=1.7 in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from geopandas->earthpy) (1.8.5)
# Requirement already satisfied: pandas>=1.0.0 in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from geopandas->earthpy) (1.5.1)
# Requirement already satisfied: pyproj>=2.6.1.post1 in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from geopandas->earthpy) (3.4.0)
# Requirement already satisfied: click-plugins in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from rasterio->earthpy) (1.1.1)
# Requirement already satisfied: setuptools in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from rasterio->earthpy) (65.5.0)
# Requirement already satisfied: snuggs>=1.4.1 in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from rasterio->earthpy) (1.4.7)
# Requirement already satisfied: certifi in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from rasterio->earthpy) (2022.9.24)
# Requirement already satisfied: attrs in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from rasterio->earthpy) (22.1.0)
# Requirement already satisfied: cligj>=0.5 in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from rasterio->earthpy) (0.7.2)
# Requirement already satisfied: click>=4.0 in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from rasterio->earthpy) (8.1.3)
# Requirement already satisfied: affine in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from rasterio->earthpy) (2.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from requests->earthpy) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from requests->earthpy) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from requests->earthpy) (2.1.1)
# Requirement already satisfied: scipy>=1.4.1 in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from scikit-image->earthpy) (1.9.3)
# Requirement already satisfied: networkx>=2.2 in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from scikit-image->earthpy) (2.8.7)
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2022.10.10-py3-none-any.whl (210 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.3/210.3 kB 5.6 MB/s eta 0:00:00
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.4.1-cp310-cp310-macosx_10_13_x86_64.whl (4.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 28.4 MB/s eta 0:00:0000:0100:01
# Collecting imageio>=2.4.1
#   Downloading imageio-2.22.4-py3-none-any.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 22.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: munch in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from fiona>=1.8->geopandas->earthpy) (2.5.0)
# Requirement already satisfied: six>=1.7 in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from fiona>=1.8->geopandas->earthpy) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in ./anaconda3/envs/geo_env/lib/python3.10/site-packages (from pandas>=1.0.0->geopandas->earthpy) (2022.5)
# Installing collected packages: tifffile, PyWavelets, imageio, scikit-image, earthpy
# Successfully installed PyWavelets-1.4.1 earthpy-0.9.4 imageio-2.22.4 scikit-image-0.19.3 tifffile-2022.10.10
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

# %%
import matplotlib.pyplot as plt
import numpy as np
import rioxarray as rxr
import geopandas as gpd
import earthpy as et
import earthpy.spatial as es
import earthpy.plot as ep

# %%
pwd
# Out:
# '/Users/lauratsang'

# %%
os.chdir("Documents/CPS NEU GIS/GIS6345/coldspringsfire")

# %%
data = et.data.get_data('cold-springs-fire')
# Out:
# Downloading from https://ndownloader.figshare.com/files/10960109
# Extracted output to /Users/lauratsang/earth-analytics/data/cold-springs-fire/.

# %%
os.chdir(os.path.join(et.io.HOME, 'earth-analytics', 'data'))

# %%
naip_data_path = os.path.join("cold-springs-fire",
                              "naip",
                              "m_3910505_nw_13_1_20150919",
                              "crop",
                              "m_3910505_nw_13_1_20150919_crop.tif")

naip_data = rxr.open_rasterio(naip_data_path)

# View shape of the data
naip_data.shape
# Out:
# (4, 2312, 4377)

# %%
naip_ndvi = es.normalized_diff(naip_data[3], naip_data[0])

# %%
ep.plot_bands(naip_ndvi,
              cmap='PiYG',
              scale=False,
              vmin=-1, vmax=1,
              title="NAIP Derived NDVI\n 19 September 2015 - Cold Springs Fire, Colorado")
plt.show()
